# %%
import json
import re

# %%
nameToPkMap = {
  "아이리시 위스키": 101,
  "내추럴 화이트 와인": 21,
  "리큐르": 33,
  "주정강화(마데이라) 와인": 121,
  "트리펠": 137,
  "필스너 맥주": 143,
  "위트 비어": 112,
  "프렌치 몰트 위스키": 140,
  "무알콜 맥주": 48,
  "테네시 위스키": 135,
  "RTD 칵테일": 148,
  "스타우트": 87,
  "약주": 104,
  "증류주": 124,
  "싱글 그레인 위스키": 91,
  "맥주(Hazy Pale Ale)": 43,
  "내추럴 스파클링 와인": 19,
  "맥주(Hazy IPA)": 42,
  "벨지안 에일": 63,
  "스파클링": 88,
  "로제 와인": 32,
  "와인": 3,
  "글루바인": 9,
  "샹그리아": 81,
  "아와모리": 97,
  "싱글몰트 위스키": 93,
  "꼬냑": 15,
  "리큐르 증류주": 34,
  "샴페인": 80,
  "기타주류": 11,
  "전통 소주": 118,
  "맥주(Kriek)": 44,
  "배럴 에이지드 임페리얼 스타우트": 54,
  "마데이라 와인": 37,
  "버번 배럴 에이지드 임페리얼 스타우트": 58,
  "크레망(스파클링 와인)": 134,
  "다크럼": 23,
  "바이스비어": 52,
  "스웨덴 싱글몰트 위스키": 83,
  "일반 증류주": 113,
  "쿼드루펠": 132,
  "피스코": 142,
  "오렌지 와인": 108,
  "콘 위스키": 131,
  "주정강화 와인": 120,
  "캐내디언 위스키": 129,
  "배럴 에이지드 스타우트": 53,
  "맥주(메르첸)": 39,
  "까바": 12,
  "블렌디드 아이리시 위스키": 72,
  "아이스와인": 102,
  "주정강화(포트) 와인": 122,
  "페일 라거 맥주": 138,
  "로제 샴페인": 31,
  "블렌디드 위스키": 73,
  "크레망": 133,
  "맥주(Strong Belgian Brown Ale)": 46,
  "내추럴 스파클링 로제 와인": 18,
  "맥주(Pale Ale)": 45,
  "레드와인": 30,
  "진 리큐르": 126,
  "밀맥주": 51,
  "허니 리큐르": 144,
  "막걸리": 4,
  "복비어": 68,
  "블렌디드 위스키 - 캐스크 스트렝스": 74,
  "내추럴 로제 와인": 17,
  "데킬라": 24,
  "블렌디드그레인 위스키": 75,
  "벨지안 화이트": 64,
  "일본 소주": 114,
  "다크 럼": 22,
  "디저트 와인": 25,
  "블렌디드 그레인 위스키": 70,
  "위스키": 111,
  "리큐르, 사케": 35,
  "임페리얼 스타우트": 115,
  "스카치 블렌디드 위스키": 85,
  "무알콜 와인": 49,
  "아이리시 싱글몰트 위스키": 100,
  "증류식 소주": 123,
  "그레인 위스키": 8,
  "블렌디드몰트 위스키": 76,
  "미분류": 149,
  "커피 리큐르": 130,
  "스파클링 에일": 89,
  "메즈칼": 47,
  "보리소주": 67,
  "애비 에일": 103,
  "맥주": 2,
  "레드 와인": 29,
  "맥주(배럴 에이지드 임페리얼 스타우트)": 40,
  "우리술": 109,
  "깔바도스(뽀모 드 노르망디)": 14,
  "고량주": 6,
  "그라파": 7,
  "쌀 소주": 94,
  "매실주": 38,
  "버무스": 57,
  "벨지안 골든 스트롱 에일": 61,
  "포트 와인": 139,
  "IPA 맥주": 147,
  "화이트 와인": 145,
  "깔바도스": 13,
  "캐나디안 위스키": 128,
  "아이리시 블렌디드 위스키": 98,
  "살균 약주": 79,
  "아르마냑": 95,
  "진": 125,
  "재패니즈 위스키": 117,
  "에비 에일": 105,
  "벨기에 다크 에일": 60,
  "토카이 와인": 136,
  "사케": 78,
  "버번 위스키": 59,
  "보드카": 65,
  "아메리칸 위스키": 96,
  "엑스트라 페일 에일(Extra Pale Ale)": 106,
  "내추럴 와인(펫낫)": 20,
  "사이더": 77,
  "싱글몰트 아이리시 위스키": 92,
  "전통주": 119,
  "스위트 와인": 84,
  "브랜디": 69,
  "플레미쉬 레드 에일": 141,
  "소주": 1,
  "보리 소주": 66,
  "블렌디드 몰트 위스키": 71,
  "스파클링 와인": 90,
  "내추럴 레드 와인": 16,
  "기타 주류": 10,
  "라이 위스키": 27,
  "맥주(앰버 라거)": 41,
  "스카치 에일": 86,
  "벨지안 스페셜 블론드": 62,
  "아이리시 싱글 그레인 위스키": 99,
  "오드비": 107,
  "미드": 50,
  "배럴 에이지드 임페리얼 포터": 55,
  "청주": 127,
  "재패니스 위스키": 116,
  "라거 맥주": 26,
  "수제맥주": 82,
  "IPA": 146,
  "고구마 소주": 5,
  "럼": 28,
  "리큐르(우리술)": 36,
  "백주": 56,
  "웨일즈 싱글몰트 위스키": 110
}

# %%
def getATypePK(name):
    if name in nameToPkMap:
        return nameToPkMap[name]
    else:
        return nameToPkMap['미분류']

def average_decimal_from_percentage_range(percentage_range):
    # Split the range into lower and upper bounds
    lower, upper = map(float, percentage_range.strip('%').split('~'))

    # Calculate the average
    average_decimal = (lower + upper) / 2

    return average_decimal

def preprocessDegree(degree):
    try:
        if '~' in degree:
            return float(average_decimal_from_percentage_range(degree))
        result = float(degree.replace('%', ''))
    except:
        pattern = "[-+]?\d*\.?\d+"
        result = re.search(pattern, degree).group(0)
    return result
def preprocessVolume(volume):
    try:
        result = int(volume.replace('ml', '').replace('m', '').replace('mL', ''))
    except:
        pattern = "[-+]?\d*\.?\d+"
        result = re.search(pattern, volume).group(0)
    return int(round(float(result)))

# %%
file_path = '/Users/dongseoklee/Downloads/result.json'

# Read JSON data from the file
with open(file_path, 'r') as file:
    data = json.load(file)

resultDataList = []
for item in data:
    resultDataList.append({
  "alcoholName": item['title'],
  "alcoholTypeNo": getATypePK(item['info']['variant']),
  "degree": preprocessDegree(item['info']['degree']),
  "volume": preprocessVolume(item['info']['volume']),
  "taste": item['taste']
})

# %%
resultDataList[-2]
# Out:
# {'alcoholName': ' 짐빔 화이트',
#  'alcoholTypeNo': 59,
#  'degree': 40.0,
#  'volume': 750,
#  'taste': {'Aroma': '달콤한, 부드러운, 바닐라',
#   'Taste': '달콤한, 캐러멜, 바닐라',
#   'Finish': '오크, 견과류, 강렬한'}}

# %%
import requests
import time
start_time = time.time()
url = 'http://localhost:8080/alcohols'
headers = {
    'Authorization': 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJ0b2tlblR5cGUiOiJOT1JNQUxfVE9LRU4iLCJ1c2VyTm8iOjIsInVzZXJJZCI6ImFwcGxlIiwiYXV0aG9yaXRpZXMiOiJST0xFX1VTRVIiLCJleHAiOjE3MDIxNDA4NTJ9.HN5HBN9eJ5GOQc1LVGsdS2bB8mmhipcOGjCR1GZFbuUVBeVnVudJr20Px51iSIMUgZVb-3-HWjHHfmnAJR1zmw'
}
# requests.post(url, json=resultDataList[-2], headers=headers)
resultList = []
for idx, item in enumerate(resultDataList):
    if idx % 100 == 0:
        print(idx)
        end_time = time.time()
        elapsed_time = end_time - start_time
        print(f"Time spent: {elapsed_time} seconds")
    result = requests.post(url, json=item, headers=headers)
    resultList.append(result)
# Out:
# 0
# Time spent: 0.0005037784576416016 seconds
# 100
# Time spent: 2.3976569175720215 seconds
# 200
# Time spent: 4.399032831192017 seconds
# 300
# Time spent: 6.423213958740234 seconds
# 400
# Time spent: 8.675644874572754 seconds
# 500
# Time spent: 11.454974889755249 seconds
# 600
# Time spent: 13.775301933288574 seconds
# 700
# Time spent: 16.026554822921753 seconds
# 800
# Time spent: 18.560529947280884 seconds
# 900
# Time spent: 21.04695200920105 seconds
# 1000
# Time spent: 23.664711952209473 seconds
# 1100
# Time spent: 26.370426893234253 seconds
# 1200
# Time spent: 29.24735689163208 seconds
# 1300
# Time spent: 32.33311891555786 seconds
# 1400
# Time spent: 35.3498649597168 seconds
# 1500
# Time spent: 39.01486897468567 seconds
# 1600
# Time spent: 42.23234796524048 seconds
# 1700
# Time spent: 45.475361824035645 seconds
# 1800
# Time spent: 48.78619885444641 seconds
# 1900
# Time spent: 52.07514190673828 seconds
# 2000
# Time spent: 55.49247479438782 seconds
# 2100
# Time spent: 59.141927003860474 seconds
# 2200
# Time spent: 62.84601187705994 seconds
# 2300
# Time spent: 66.5096538066864 seconds
# 2400
# Time spent: 70.4407548904419 seconds
# 2500
# Time spent: 74.2739417552948 seconds

# %%
type(resultList[0])
# Out:
# requests.models.Response

# %%
from collections import defaultdict
stat_dict = defaultdict(int)
for result in resultList:
    stat_dict[result.status_code] += 1

# %%
stat_dict
# Out:
# defaultdict(int, {400: 53, 201: 2507})
